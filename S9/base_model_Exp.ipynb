# %%
from utils import *
from last_model import *

# %%
model = BaseModel()
get_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 32, 32]             896
#               ReLU-2           [-1, 32, 32, 32]               0
#        BatchNorm2d-3           [-1, 32, 32, 32]              64
#            Dropout-4           [-1, 32, 32, 32]               0
#             Conv2d-5           [-1, 50, 32, 32]          14,450
#               ReLU-6           [-1, 50, 32, 32]               0
#        BatchNorm2d-7           [-1, 50, 32, 32]             100
#            Dropout-8           [-1, 50, 32, 32]               0
#             Conv2d-9           [-1, 50, 32, 32]          14,450
#              ReLU-10           [-1, 50, 32, 32]               0
#       BatchNorm2d-11           [-1, 50, 32, 32]             100
#           Dropout-12           [-1, 50, 32, 32]               0
#            Conv2d-13           [-1, 72, 17, 17]          32,472
# ...
