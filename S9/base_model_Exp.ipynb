# %%
from utils import *
from model_final
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from utils import *
# ----> 2 from model_final import *
#
# ModuleNotFoundError: No module named 'model_final'

# %%
model = BaseModel()
get_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 30, 30]             896
#               ReLU-2           [-1, 32, 30, 30]               0
#        BatchNorm2d-3           [-1, 32, 30, 30]              64
#            Dropout-4           [-1, 32, 30, 30]               0
#             Conv2d-5           [-1, 64, 28, 28]          18,496
#               ReLU-6           [-1, 64, 28, 28]               0
#        BatchNorm2d-7           [-1, 64, 28, 28]             128
#            Dropout-8           [-1, 64, 28, 28]               0
#             Conv2d-9           [-1, 64, 15, 15]          36,928
#            Conv2d-10           [-1, 64, 15, 15]             640
#            Conv2d-11           [-1, 56, 15, 15]           3,640
#              ReLU-12           [-1, 56, 15, 15]               0
#       BatchNorm2d-13           [-1, 56, 15, 15]             112
# ...
