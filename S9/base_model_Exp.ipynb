# %%
from utils import *
from last_model import *

# %%
model = BaseModel()
get_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 32, 30, 30]             896
#               ReLU-2           [-1, 32, 30, 30]               0
#        BatchNorm2d-3           [-1, 32, 30, 30]              64
#            Dropout-4           [-1, 32, 30, 30]               0
#             Conv2d-5           [-1, 64, 30, 30]          18,496
#               ReLU-6           [-1, 64, 30, 30]               0
#        BatchNorm2d-7           [-1, 64, 30, 30]             128
#            Dropout-8           [-1, 64, 30, 30]               0
#             Conv2d-9           [-1, 72, 16, 16]          41,544
#            Conv2d-10           [-1, 72, 16, 16]             720
#            Conv2d-11           [-1, 56, 16, 16]           4,088
#              ReLU-12           [-1, 56, 16, 16]               0
#       BatchNorm2d-13           [-1, 56, 16, 16]             112
# ...
