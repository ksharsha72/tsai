# %%
from utils import *
from model_2 import *

# %%
model = Model()
get_summary(model)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 16, 30, 30]             448
#               ReLU-2           [-1, 16, 30, 30]               0
#        BatchNorm2d-3           [-1, 16, 30, 30]              32
#            Dropout-4           [-1, 16, 30, 30]               0
#             Conv2d-5           [-1, 24, 28, 28]           3,480
#               ReLU-6           [-1, 24, 28, 28]               0
#        BatchNorm2d-7           [-1, 24, 28, 28]              48
#            Dropout-8           [-1, 24, 28, 28]               0
#             Conv2d-9           [-1, 24, 28, 28]           3,480
#              ReLU-10           [-1, 24, 28, 28]               0
#       BatchNorm2d-11           [-1, 24, 28, 28]              48
#           Dropout-12           [-1, 24, 28, 28]               0
#            Conv2d-13           [-1, 32, 13, 13]           6,944
# ...
